# %% [markdown]
# # Demonstration

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv("/workspaces/data/etasl_node/fourbar.csv",sep="\s*,\s*",engine="python")
A=data.to_numpy()
print(data.columns)
# Out:
#    delta_qr      delta_qx      delta_qy  delta_qz  delta_x  delta_y  delta_z  \
# 0  0.707814  1.451383e-13 -1.450301e-10  0.706399  0.00395  -0.3086  0.37685
#
#    elbow_joint  shoulder_lift_joint  shoulder_pan_joint  ...     target_qy  \
# 0     1.570796            -1.570796                 0.0  ... -1.450301e-10
#
#    target_qz  target_x  target_y  target_z   time  wrist_1_joint  \
# 0   0.706399   0.00395   -0.3086   0.37685  0.002      -1.570796
#
#    wrist_2_joint  wrist_3_joint  Unnamed: 21
# 0      -1.570796            0.0          NaN
#
# [1 rows x 22 columns]
# Index(['delta_qr', 'delta_qx', 'delta_qy', 'delta_qz', 'delta_x', 'delta_y',
#        'delta_z', 'elbow_joint', 'shoulder_lift_joint', 'shoulder_pan_joint',
#        'target_qr', 'target_qx', 'target_qy', 'target_qz', 'target_x',
#        'target_y', 'target_z', 'time', 'wrist_1_joint', 'wrist_2_joint',
#        'wrist_3_joint', 'Unnamed: 21'],
#       dtype='object')

# %%
data.plot(x='time',y=['shoulder_pan_joint','shoulder_lift_joint','elbow_joint','wrist_1_joint','wrist_2_joint','wrist_3_joint'])
# Out:
# <AxesSubplot:xlabel='time'>

# %%
data.plot(x='time',y=['delta_x','delta_y','delta_z'])
# Out:
# <AxesSubplot:xlabel='time'>

# %%
data.plot(x='time',y=['delta_qx','delta_qy','delta_qz','delta_qr'])
# Out:
# <AxesSubplot:xlabel='time'>

# %%
data.plot(x='target_x', y='target_y')
plt.axis('equal')
# Out:
# (-0.02545576502335295,
#  0.00535027459817675,
#  -0.32403075827874256,
#  0.01545032160794577)

# %%
data['time'].to_numpy()
# Out:
# array([2.0000e-03, 4.0000e-03, 6.0000e-03, ..., 3.5554e+01, 3.5556e+01,
#        3.5558e+01])

# %%
data.columns
# Out:
# Index(['delta_qr', 'delta_qx', 'delta_qy', 'delta_qz', 'delta_x', 'delta_y',
#        'delta_z', 'elbow_joint', 'shoulder_lift_joint', 'shoulder_pan_joint',
#        'target_qr', 'target_qx', 'target_qy', 'target_qz', 'target_x',
#        'target_y', 'target_z', 'time', 'wrist_1_joint', 'wrist_2_joint',
#        'wrist_3_joint', 'Unnamed: 21'],
#       dtype='object')
